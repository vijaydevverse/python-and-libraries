# %% [markdown]
# <a href="https://colab.research.google.com/github/vijaydevverse/python-and-libraries/blob/main/Matplotlib/MatplotlibV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Matplotlib
#
# It is used to show the data in graphically to the user

# %%
import matplotlib

# %%
#checking matplotlib version

print(matplotlib.__version__)
# Out:
# 3.10.0

# %% [markdown]
# ##Matplotlib Pyplot
#
# Most of the Matplotlib utilities are lies under pyplot submodule.

# %%
#Draw a line in a diagram from position (0,0) to position (6,250)

import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,6])
ypoints=np.array([0,250])
plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# ##Matplotlib plotting

# %% [markdown]
# ###Plotting x and y points

# %%
#plot a line from (1,3) to(8,10)
import matplotlib.pyplot as plt
import numpy as np

xpoint=np.array([1,8])
yponts=np.array([3,10])
plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# ###plotting without line

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoint=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoint,ypoints,'o')#'o' markes the points without a line
plt.show()

# %%
#Draw a line in a diagram from position (1,3) to (2,8) then to (6,1) and finally to position(8,10)


import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# ###Default x points
#
# If we do not specify the points in the x axis ,they will get the default values 0,1,2,3

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10,5,7])
plt.plot(ypoints)
plt.show()

# %% [markdown]
# ##Matplotlib Markers

# %%
#Mark each pont with a circle

import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='o') #circle marker
plt.show()

# %%
#'*' marker

import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='*')
plt.show()

# %% [markdown]
# ###Format strings fmt
#
# You can use the shortcut string notation parameter to specify the marker
#
# Marker|line|color

# %%
#Mark each point with red circle and dotted line

import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])
plt.plot(ypoints,'o:r') #'o' for circle,r for red,:for dotted lines
plt.show()

# %% [markdown]
# ###Marker size
#
# ms is used to set the marker size

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='o',ms=20)
plt.show()

# %% [markdown]
# ###Marker color
#
# markeredgecolor or mec used to set the color of the edge of the markers.

# %%
#set the edge colour to red

import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='o',ms=20,mec='r')
plt.show()

# %% [markdown]
# ###markerface color
# mfc -used to change the maker face color

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='o',ms=20,mec='r',mfc='g')
plt.show()

# %% [markdown]
# ##Matplotlib Line
#
# The argument used for this will be linestyle or ls

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])
plt.plot(ypoints,linestyle='dotted')
plt.show()

# %% [markdown]
# ###Line color
#
# use color or c to set clor of line

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,color='r')
plt.show()

# %% [markdown]
# ###line width
#
# we can specify line width using linewidth or lw keyword

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,linewidth='20.5')
plt.show()

# %% [markdown]
# ###Multiple lines

# %%
import matplotlib.pyplot as plt
import numpy as np
y1=np.array([3,8,1,10])
y2=np.array([6,2,7,11])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=np.array([0,1,2,3])
y1=np.array([3,8,1,10])
x2=np.array([0,1,2,3])
y2=np.array([6,2,7,11])
plt.plot([6,2,7,11])
plt.plot(x1,y1,x2,y2)
plt.show()

# %% [markdown]
# ##Matplotlib labels and title
#
# xlabel(),ylabel() function used to set  label for x axis and y axis

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)
plt.xlabel("Average pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %% [markdown]
# ## Create a Title for a plot

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %% [markdown]
# ###Set Font properties for title and labels
#
# we can use the fontdict parameter in xlabel(),ylabel() and title to set font properties for the title and labels

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'darkred','size':15}
plt.title("Sports Watch Data", fontdict=font1)
plt.xlabel("Average Pulse", fontdict=font2)
plt.ylabel("Calorie Burnage", fontdict=font2)
plt.plot(x,y)
plt.show()

# %% [markdown]
# ###Position the title
# use loc parameter in title()  to position the title

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'darkred','size':15}
plt.title("Sports Watch Data", fontdict=font1,loc='left')
plt.xlabel("Average Pulse",fontdict=font2)
plt.ylabel("Caloie Burnage",fontdict=font2)
plt.plot(x,y)
plt.show()

# %% [markdown]
# ##Matplotlib Adding Grid Lines
#
# you can use grid() function to add  grid lines to the plot

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)
plt.title("Sports Watch Data")
plt.xlabel("Average pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y)
plt.grid(axis='x')
plt.show()

# %% [markdown]
# ###Properties of grid
#
# grid(color='color',linestyle='linestyle',linewidth=number)

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)
plt.title("Sports Watch Data")
plt.xlabel("Average pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y)
plt.grid(color='green',linestyle='--',linewidth=0.5)
plt.show()

# %% [markdown]
# ##Matplotlib Subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)  #1 row,2 columns,1st plot
plt.plot(x,y)

#plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2) #1st row,2 columns,2nd plot
plt.plot(x,y)
plt.show()

# %%
#6 subplots

import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,2)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,3)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,4)
plt.plot(x,y)


x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,5)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,6)
plt.plot(x,y)
plt.show()

# %% [markdown]
# ###Title for subplots

# %%
import matplotlib.pyplot as plt
import numpy as np
#Plot 1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("Sales")
#Plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("Income")
plt.suptitle("My Shop")
plt.show()

# %% [markdown]
# #Matplotlib Scatter
#
# scatter() function plots one dot for each observation.It needs two arrays of the same length,one for the values of the x-axis,and one for values on the y-axis.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)
plt.show()

# %%
#Draw two plots on the same figure
import matplotlib.pyplot as plt
import numpy as np
#day 1,the age and speed of 13 cars
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)

#day2,the age and speed of 15 cars
x=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y=np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ##Colors
#
# we can set color for each scatter plot with the color or the c argument

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arrayx=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y,color="hotpink")

x=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y=np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x,y,color='#88c999')
plt.show()

# %% [markdown]
# ###Color each dot
#
# we can set color for each dot using an array of colors as value for the c argument

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

colors=np.array(["red","blue","green","black","yellow","purple","cyan","beige","gold","gray","orange","hotpink","magenta"])
plt.scatter(x,y,c=colors)
plt.show()

# %% [markdown]
# ##ColorMap
#
# A colormap is like a list of colors,where each color has a value that ranges from 0 to 100

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors=np.array([0,10,20,30,40,45,50,55,60,70,80,90,100])
plt.scatter(x,y,c=colors,cmap='viridis')
plt.colorbar()
plt.show()

# %% [markdown]
# ##Size
# You can change the size of the dots with the s argument

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes=np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.scatter(x,y,s=sizes)
plt.show()

# %% [markdown]
# ##Alpha
# You can adjust the transparence of the dots with the alpha argument

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes=np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.scatter(x,y,s=sizes,alpha=0.5)
plt.show()

# %%
#Combine color,size and Alpha

import matplotlib.pyplot as plt
import numpy as np
x=np.random.randint(100,size=(100))
y=np.random.randint(100,size=(100))
colors=np.random.randint(100,size=(100))
sizes=10*np.random.randint(100,size=(100))
plt.scatter(x,y,c=colors,s=sizes,alpha=0.5,cmap='nipy_spectral')
plt.colorbar()
plt.show()

# %% [markdown]
# #Matplotlib Bars
#
# We can use the bar() function to draw bar graphs

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=["Apples","Bananas"]
y=[400,350]
plt.bar(x,y)
plt.show()

# %% [markdown]
# ##Horizontal Bars
#
# use the barh() function

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,2,10])
plt.barh(x,y)
plt.show()

# %% [markdown]
# ##Bar Color

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,2,10])
plt.bar(x,y,color="purple")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,2,10])
plt.bar(x,y,color="yellow")
plt.show()

# %% [markdown]
# ##Bar width
#
# bar() takes the keyword argument width to set the width of the bars

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,2,10])
plt.bar(x,y,width=0.1)
plt.show()

# %% [markdown]
# ##Bar height

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,2,10])
plt.barh(x,y,height=0.1)
plt.show()

# %% [markdown]
# #Matplotlib Histogram
#
# Histogram is a graph showing frequency distributions.
#
# *   We use the hist() function to create histogram

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.normal(170,10,250)
print(x)
plt.hist(x)
plt.show()
# Out:
# [168.43585027 166.85390304 168.73390296 177.06859037 185.89053901
#  171.90044493 171.04616101 165.53480862 159.30367529 164.19651412
#  156.9091392  180.89918281 177.78136156 171.26718424 160.74274219
#  202.83002749 181.45262097 149.85875838 168.2048587  157.60904326
#  160.47609776 158.20338017 164.89460164 169.53594566 150.42248677
#  160.19547431 175.48297679 162.09339882 165.33025188 164.59807904
#  164.97950497 172.60029219 170.43896967 157.29438481 182.63389925
#  160.13157805 189.22322098 184.02976856 171.4070864  170.44681633
#  162.95731379 167.5797045  161.92268818 148.98418418 168.71839266
#  159.26098672 162.95666675 178.94536574 182.03116504 178.33407422
#  174.17912383 164.62848132 173.88525566 159.87244278 166.6550461
#  173.80452357 183.95938856 155.43656906 165.5485896  159.45037782
#  169.36537262 163.59367516 174.03073665 179.94095628 186.4673375
#  182.86884258 172.2279498  166.36592485 173.81873187 180.74363758
# ...

# %% [markdown]
# #Matplotlib Pie Charts
#
# pie() function is used to draw pie chart

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])  #by default plotting of the 1st wedge from the x axis and move counterclockwise
plt.pie(y)
plt.show()

# %% [markdown]
# ##Labels
# it is used to give label for each part

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","Banana","Cherries","Dates"]
plt.pie(y,labels=mylabels)
plt.show()

# %% [markdown]
# ##Start Angle
#
# Default angle is at the x-axis,The start angle parameter is defined with an angle in degrees,default angle is 0.

# %%
#Start the 1st wedge at 90 degrees
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","Bananas","Cheries","Dates"]
plt.pie(y,labels=mylabels,startangle=90) #start at 90 counter clockwise
plt.show()

# %% [markdown]
# ##Explode
#
# May be you want one of the wedges to stand out,the explode parameter allows you to do that.

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","Bananas","Cheries","Dates"]
myexplode=[0.2,0,0,0]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.show()

# %% [markdown]
# ##Shadow
# Add a shadow to the pie chart by setting the shadows parameter to True.

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","Bananas","Cheries","Dates"]
myexplode=[0.2,0,0,0]
plt.pie(y,labels=mylabels,explode=myexplode,shadow=True)
plt.show()

# %% [markdown]
# Colors

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","Bananas","Cherries","Dates"]
mycolors=["black","hotpink","b","#4CAF50"]
plt.pie(y,labels=mylabels,colors=mycolors)
plt.show()

# %% [markdown]
# ##Legend
#
#
# To add a list of explanation for each wedge,use the legend() function

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","Bananas","Cherries","Dates"]
plt.pie(y,labels=mylabels)
plt.legend(title="Four Fruits:")
plt.show()

# %% [markdown]
# #Waffle Chart
#
#
#
# *   A waffle chart is basically a square display,usually consisting of 100 smaller squares arranged in a 10 by 10 layout
# *   The squares are colored according to the proportions you are aiming to visualize
#
#
# *   similarly to how you would color different slices of a pie chart.As this square layout somewhat resembles a delicious waffle

# %%
pip install pywaffle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.6/25.6 MB 46.1 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from  pywaffle import Waffle
fig=plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=10,
    values=[48,46,6],
    figsize=(5,3)
)
plt.show()
# Out:
# <Waffle size 500x300 with 1 Axes>

# %% [markdown]
# ##Values in dict and Auto-sizing

# %%
import matplotlib.pyplot as plt
import numpy as np
data={'Democratic':48,'Republican':46,'Libertarian':3}
fig=plt.figure(FigureClass=Waffle,rows=5,values=data,legend={'loc':'upper left','bbox_to_anchor':(1.1,1)})
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %% [markdown]
# ##Title,legend,colors,Background colors,direction and style

# %%
import matplotlib.pyplot as plot
from  pywaffle import Waffle
data={'Democratic':48,'Republican':46,'Libertarian':3}
fig=plt.figure(
    FigureClass=Waffle,
    rows=5,
    values=data,
    colors=["#232066","#983D3D","#DCB732"],
    title={'label':'Vote percentage in 2016 US Precidential Election','loc':'left'},
    labels=[f"{k} ({v}%)"for k,v in data.items()],
    legend={'loc':'lower left','bbox_to_anchor':(0,-0.4),'ncol':len(data),'framealpha':0},
    starting_location='NW',
    block_arranging_style= 'snake'
)
fig.set_facecolor('#EEEEEE')
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %% [markdown]
# ##Plot  with Icons-Pictogram  Chart

# %%
data={'Democratic':48,'Republican':46,'Libertarin':3}
fig=plt.figure(FigureClass=Waffle,rows=5,values=data,colors=["#232066","#983D3D","#DCB732"],legend={'loc':'upper left','bbox_to_anchor':(1,1)},icons='child',font_size=12,icon_legend=True)
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %% [markdown]
# #Word Cloud
# It is a data visualization technique used for representing text data in which the size of each word indicates its frequency or importance.

# %%
pip install wordcloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud #correct import
text=("oh oh oh oh oh versewrote book stand title book would life superman that make feel"
"count privilege love ideal honoured know feel see everyday things say rock baby truth"
"rock love rock everything need rock baby rock wannanplease the sun")
#Create the WordCloud object
wc=WordCloud(width=480,height=480,margin=0).generate(text)
#Display the generated image
plt.imshow(wc,interpolation='bilinear')
plt.axis("off")
plt.margins(x=0,y=0)
plt.show()
